# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
with fits.open('ae101005090xi0_0_3x3n066z_uf.evt.gz.txt') as hdu:
 
    science_data1 = hdu[1].data
    science_header1 = hdu[1].header
 
    #error_data2 = hdu['err',2].data
    #error_header2 = hdu['err',2].header

# %%
science_data1
# Out:
# FITS_rec([(1, 185,  58, 326,  58, 698,  59, 957, 326, -397,  471,           0, [  60,    3,    1,    4,    0,   -3,   -1,    1,   -1],   59,   61,   59, 0,     0, -18, 2538,  4283269185, 2.19351218e+08, 2.19351234e+08, 0,  0, 2.19351214e+08, 2.19351214e+08),
#           (1, 207, 462, 304, 462, 720, 463, 979, 730,  -20,  325,        4096, [ 156,    4,    0,   -1,    1,   -5,   -2,   -1,   -2],  160,  158,  161, 0,     0,  -5, 2538,  4283269185, 2.19351218e+08, 2.19351234e+08, 0,  1, 2.19351214e+08, 2.19351214e+08),
#           (1, 183, 593, 328, 593, 696, 594, 955, 862,  113,  307,   536870912, [  50,    7,    5,    7,   32,   48,   25,   39,   47],  247,  239,  245, 7, -1553,  22, 2538,  4283269185, 2.19351218e+08, 2.19351234e+08, 0,  2, 2.19351214e+08, 2.19351214e+08),
#           ...,
# ...

# %%
science_header1
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  100 / width of table in bytes
# NAXIS2  =               373249 / Number of events
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   27 / number of fields in each row
# TTYPE1  = 'SEGMENT '           / Segment number
# TFORM1  = '1I      '           / data format of field: 2-byte INTEGER
# TTYPE2  = 'RAWX    '           / Raw X coordinate
# TFORM2  = '1I      '           / data format of field: 2-byte INTEGER
# TUNIT2  = 'pixel   '           / physical unit of field
# TTYPE3  = 'RAWY    '           / Raw Y coordinate
# TFORM3  = '1I      '           / data format of field: 2-byte INTEGER
# TUNIT3  = 'pixel   '           / physical unit of field
# ...

# %%
plt.imshow()
